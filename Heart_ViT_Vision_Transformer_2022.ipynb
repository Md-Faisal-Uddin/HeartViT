# %%
#Drive mounted
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#use to unzip file
import zipfile
with zipfile.ZipFile("/content/drive/MyDrive/Heart_ViT_2022/Wav_data/WAV_data.zip","r") as zip_ref:
    zip_ref.extractall("/content/drive/MyDrive/Heart_ViT_2022/Wav_data/wave*")

# %% [markdown]
# **(Dataset collected from physionet which is benchmark dataset)**
# based on **ID (Person)**
# 1. **AV** (**.**wave, **.**hea, **.**tsv)
# 2. **MV** ( **.**wave, **.**hea, **.**tsv)
# 3. **PV** (**.**wave, **.**hea, **.**tsv)
# 4. **TV** (**.**wave, **.**hea, **.**tsv)

# %%
#meta data which contain overall information about heart sound (AV, MV, PV, TV)
#read csv file for class separation
import pandas as pd
path = "/content/drive/MyDrive/Heart_ViT_2022/meta_data.csv"
meta_data = pd.read_csv(path)

# %%
meta_data.head(10)
# Out:
#    Patient ID Recording locations:    Age     Sex  Height  Weight  \
# 0        2530          AV+PV+TV+MV  Child  Female    98.0   15.90
# 1        9979          AV+PV+TV+MV  Child  Female   103.0   13.10
# 2        9983          AV+PV+TV+MV  Child    Male   115.0   19.10
# 3       13918          AV+PV+TV+MV  Child    Male    98.0   15.90
# 4       14241          AV+PV+TV+MV  Child    Male    87.0   11.20
# 5       14998          AV+PV+TV+MV  Child    Male     NaN     NaN
# 6       23625          AV+PV+TV+MV  Child  Female    92.0   14.00
# 7       24160          AV+PV+TV+MV  Child  Female    98.0   17.66
# 8       29045          AV+PV+TV+MV  Child  Female    88.0   12.50
# 9       29378                AV+MV  Child  Female    82.0   10.70
#
#    Pregnancy status   Murmur Murmur locations Most audible location  ...  \
# 0             False   Absent              NaN                   NaN  ...
# 1             False  Present      AV+MV+PV+TV                    TV  ...
# ...

# %% [markdown]
# **Dataset = 10419 [ .wave = 3159 (AV=800, PV=861, MV=766, TV=732), .txt = 942, .tsv = 3159,** .**hea = 3159** ]

# %%
#all file count
from glob import glob
#audio_file = glob('../content/drive/MyDrive/unzip/AV/*.wav')
total_file = glob('../content/drive/MyDrive/Heart_ViT_2022/training_data/*')

# %%
len(total_file)
# Out:
# 10419

# %%
#text file count
from glob import glob
#audio_file = glob('../content/drive/MyDrive/unzip/AV/*.wav')
txt_file = glob('../content/drive/MyDrive/Heart_ViT_2022/training_data/*.txt')

# %%
len(txt_file)
# Out:
# 942

# %%
#tsv file count
from glob import glob
#audio_file = glob('../content/drive/MyDrive/unzip/AV/*.wav')
tsv_file = glob('../content/drive/MyDrive/Heart_ViT_2022/training_data/*.tsv')

# %%
len(tsv_file )
# Out:
# 3159

# %%
#hea file count
from glob import glob
#audio_file = glob('../content/drive/MyDrive/unzip/AV/*.wav')
hea_file = glob('../content/drive/MyDrive/Heart_ViT_2022/training_data/*.hea')

# %%
len(hea_file)
# Out:
# 3159

# %%
#wave file count
wave_files = glob('../content/drive/MyDrive/Heart_ViT_2022/training_data/*.wav')

# %%
len(wave_files)
# Out:
# 3159

# %%
#analysis an sample audio

# %%
import librosa
import librosa.display
import IPython.display as ipd
ipd.Audio(wave_files[2])
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio("/content/drive/MyDrive/Heart_ViT_2022/WAV_data/AV_wav/29045_AV.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
i="/content/drive/MyDrive/Heart_ViT_2022/WAV_data/AV_wav/29045_AV.wav"
import matplotlib.pyplot as plt
y, sr = librosa.load(i,duration=10)
plt.figure()
#plt.subplot(3, 1, 1)
librosa.display.waveplot(y, sr=sr)
#plt.title('Monophonic')

# %%
from IPython.display import display, Image
display(Image(filename='/content/drive/MyDrive/Heart_ViT_2022/Wave_to_Images/AV/AV_wve_img/Abnormal/13918_AV.png'))

# %%
#total files in dataset(.hea, .wave, .tsv, .txt) = 10419 = 3159*3 + 942

# %%
#AV Wave files count
AV_count=0
import os
#import shutil
sourcepath='/content/drive/MyDrive/Heart_ViT_2022/training_data'
sourcefiles = os.listdir(sourcepath)
#destinationpath = '/content/drive/MyDrive/D_Thesis/WAV_data/AV_wav'
for file in sourcefiles:_AV.wav','_AV_1.wav','_AV_2.wav','_AV_3.wav
    if file.endswith(('')):
      AV_count=AV_count+1
        #shutil.move(os.path.join(sourcepath,file), os.path.join(destinationpath,file))

# %%
AV_count
# Out:
# 800

# %%
#MV wave files count
MV_count = 0
import os
#import shutil
sourcepath='/content/drive/MyDrive/Heart_ViT_2022/training_data'
sourcefiles = os.listdir(sourcepath)
#destinationpath = '/content/drive/MyDrive/D_Thesis/WAV_data/MV_wav'
for file in sourcefiles:
    if file.endswith(('_MV.wav','_MV_1.wav','_MV_2.wav')):
      MV_count = MV_count+1
        #shutil.move(os.path.join(sourcepath,file), os.path.join(destinationpath,file))

# %%
MV_count
# Out:
# 861

# %%
#PV Wave files count
PV_count=0
import os
#import shutil
sourcepath='/content/drive/MyDrive/Heart_ViT_2022/training_data'
sourcefiles = os.listdir(sourcepath)
#destinationpath = '/content/drive/MyDrive/D_Thesis/WAV_data/PV_wav'
for file in sourcefiles:
    if file.endswith(('_PV.wav','_PV_1.wav','_PV_2.wav')):
      PV_count=PV_count+1
        #shutil.move(os.path.join(sourcepath,file), os.path.join(destinationpath,file))

# %%
PV_count
# Out:
# 766

# %%
#TV wave files count
TV_count = 0
import os
#import shutil
sourcepath='/content/drive/MyDrive/Heart_ViT_2022/training_data'
sourcefiles = os.listdir(sourcepath)
#destinationpath = '/content/drive/MyDrive/D_Thesis/WAV_data/TV'
for file in sourcefiles:
    if file.endswith(('_TV.wav','_TV_1.wav','TV_2.wav')):
      TV_count = TV_count+1
        #shutil.move(os.path.join(sourcepath,file), os.path.join(destinationpath,file))

# %%
TV_count
# Out:
# 732

# %%
#total wave files = AV+MV+PV+TV = 800+861+766+732 = 3159

# %% [markdown]
# **1st steps, Wave files separated based on location (AV, MV, PV, TV) from collected dataset**

# %%
#AV Wave files seperation
import os
import shutil
sourcepath='/content/drive/MyDrive/D_Thesis/training_data'
sourcefiles = os.listdir(sourcepath)
destinationpath = '/content/drive/MyDrive/D_Thesis/WAV_data/AV_wav'
for file in sourcefiles:
    if file.endswith(('_AV.wav','_AV_1.wav','_AV_2.wav','_AV_3.wav')):
        shutil.move(os.path.join(sourcepath,file), os.path.join(destinationpath,file))

# %%
#AV wave files count
import os

# folder path
dir_path = '/content/drive/MyDrive/Heart_ViT_2022/Wav_data/wave*/WAV_data/AV_wav'
count = 0
# Iterate directory
for path in os.listdir(dir_path):
    # check if current path is a file
    if os.path.isfile(os.path.join(dir_path, path)):
        count += 1
print('File count:', count)
# Out:
# File count: 800

# %%
#MV wave files seperation
import os
import shutil
sourcepath='/content/drive/MyDrive/D_Thesis/training_data'
sourcefiles = os.listdir(sourcepath)
destinationpath = '/content/drive/MyDrive/D_Thesis/WAV_data/MV_wav'
for file in sourcefiles:
    if file.endswith(('_MV.wav','_MV_1.wav','_MV_2.wav')):
        shutil.move(os.path.join(sourcepath,file), os.path.join(destinationpath,file))

# %%
#MV Wave files count
import os

# folder path
dir_path = '/content/drive/MyDrive/Heart_ViT_2022/Wav_data/wave*/WAV_data/MV_wav'
count = 0
# Iterate directory
for path in os.listdir(dir_path):
    # check if current path is a file
    if os.path.isfile(os.path.join(dir_path, path)):
        count += 1
print('File count:', count)
# Out:
# File count: 861

# %%
#PV Wave files seperation
import os
import shutil
sourcepath='/content/drive/MyDrive/D_Thesis/training_data'
sourcefiles = os.listdir(sourcepath)
destinationpath = '/content/drive/MyDrive/D_Thesis/WAV_data/PV_wav'
for file in sourcefiles:
    if file.endswith(('_PV.wav','_PV_1.wav','_PV_2.wav')):
        shutil.move(os.path.join(sourcepath,file), os.path.join(destinationpath,file))

# %%
#PV Wave files count
import os

# folder path
dir_path = '/content/drive/MyDrive/Heart_ViT_2022/Wav_data/wave*/WAV_data/PV_wav'
count = 0
# Iterate directory
for path in os.listdir(dir_path):
    # check if current path is a file
    if os.path.isfile(os.path.join(dir_path, path)):
        count += 1
print('File count:', count)
# Out:
# File count: 766

# %%
# !mkdir "/content/drive/MyDrive/D_Thesis/WAV_data/TV"

# %%
audio_file = glob('../content/drive/MyDrive/D_Thesis/WAV_data/TV_wave/TV_wav/*.wav')

# %%
len(audio_file)
# Out:
# 732

# %%
#TV wave files seperation
import os
import shutil
sourcepath='/content/drive/MyDrive/D_Thesis/training_data'
sourcefiles = os.listdir(sourcepath)
destinationpath = '/content/drive/MyDrive/D_Thesis/WAV_data/TV'
for file in sourcefiles:
    if file.endswith(('_TV.wav','_TV_1.wav','TV_2.wav')):
        shutil.move(os.path.join(sourcepath,file), os.path.join(destinationpath,file))

# %%
#TV wave files count
import os

# folder path
dir_path = '/content/drive/MyDrive/Heart_ViT_2022/WAV_data/TV_wav'
count = 0
# Iterate directory
for path in os.listdir(dir_path):
    # check if current path is a file
    if os.path.isfile(os.path.join(dir_path, path)):
        count += 1
print('File count:', count)
# Out:
# File count: 732

# %% [markdown]
# **2nd step, using the Mel Frequency Cepstral Coefficient to convert audio data to Images (MFCC)**

# %%
#import needed library
import librosa
import librosa.display
import IPython.display as ipd
import matplotlib.pyplot as plt
import numpy as np
from glob import glob

# %%
#1. AV wave files to image

# %%
#read files matching .wave extension
audio_file = glob('../content/drive/MyDrive/D_Thesis/WAV_data/AV_wav/*.wav')

# %%
len(audio_file)
# Out:
# 800

# %%
#convert audio(AV) to images using loop
import os
for i in audio_file:
  print(i)
  #i=r "/content/drive/MyDrive/D_Thesis/WAV_data/AV_wav/14241_AV.wav"
  signal, sr = librosa.load(i)
  mfccs = librosa.feature.mfcc(y=signal, n_mfcc=40, sr=3000)
  plt.figure(figsize=(11, 3))
  a=librosa.display.specshow(mfccs)
  plt.savefig("/content/drive/MyDrive/D_Thesis/Img_to_wve_updte/AV_wve_img/"+str(os.path.basename(i).split(".")[0])+".png")
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
#read converted images file based on .png
image_file = glob('../content/drive/MyDrive/D_Thesis/Image_data/AV_wave_to_image/*.png')

# %%
len(image_file)
# Out:
# 800

# %%
#2. MV wave files to image

# %%
audio_file = glob('../content/drive/MyDrive/D_Thesis/WAV_data/MV_wav/*.wav')

# %%
len(audio_file)
# Out:
# 861

# %%
#convert audio(MV) to images using loop
import os
for i in audio_file:
  #print(i)
  signal, sr = librosa.load(i)
  mfccs = librosa.feature.mfcc(y=signal, n_mfcc=13, sr=3000)
  plt.figure(figsize=(15, 15))
  a=librosa.display.specshow(mfccs)
  plt.savefig("/content/drive/MyDrive/D_Thesis/Image_data/MV_wave_to_image/"+str(os.path.basename(i).split(".")[0])+".png")

# %%
#read converted images file based on .png
image_file = glob('../content/drive/MyDrive/D_Thesis/Image_data/MV_wave_to_image/*.png')

# %%
len(image_file)
# Out:
# 861

# %%
#3. PV wave files to image

# %%
audio_file = glob('../content/drive/MyDrive/D_Thesis/WAV_data/PV_wav/*.wav')

# %%
len(audio_file)
# Out:
# 766

# %%
#convert audio(PV) to images using loop
import os
for i in audio_file:
  #print(i)
  signal, sr = librosa.load(i)
  mfccs = librosa.feature.mfcc(y=signal, n_mfcc=13, sr=sr)
  plt.figure(figsize=(15, 15))
  a=librosa.display.specshow(mfccs)
  plt.savefig("/content/drive/MyDrive/D_Thesis/Image_data/PV_wave_to_image/"+str(os.path.basename(i).split(".")[0])+".png")

# %%
#read converted images file based on .png
image_file = glob('../content/drive/MyDrive/D_Thesis/Image_data/PV_wave_to_image/*.png')

# %%
len(image_file)
# Out:
# 766

# %%
#4. TV wave to image

# %%
from glob import glob
audio_file = glob('../content/drive/MyDrive/D_Thesis/WAV_data/TV_wave/TV_wav/*.wav')

# %%
len(audio_file)
# Out:
# 732

# %%
# !rm -r "/content/drive/MyDrive/Heart_ViT_2022/crooped_image/TV"

# %%
# !mkdir "/content/drive/MyDrive/Heart_ViT_2022/crooped_image/TV"

# %%
# !mkdir "/content/drive/MyDrive/Heart_ViT_2022/crooped_image/TV/Abnormal"
# !mkdir "/content/drive/MyDrive/Heart_ViT_2022/crooped_image/TV/Normal"

# %%
# !rm -r "/content/drive/MyDrive/Heart_ViT_2022/Wave_to_Images/TV"
# !mkdir "/content/drive/MyDrive/Heart_ViT_2022/Wave_to_Images/TV"

# %%
# !rm -r "/content/drive/MyDrive/D_Thesis/WAV_data/TV_wav"

# %%
# !rm -r "/content/drive/MyDrive/Heart_ViT_2022/Wave_to_Images/TV"

# %%
# !mkdir "/content/drive/MyDrive/Heart_ViT_2022/Wave_to_Images/TV/TV_wve_img"

# %%
# !rm -r "/content/drive/MyDrive/Heart_ViT_2022/Wave_to_Images/TV/TV_wve_img"

# %%
#convert audio(TV) to images using loop
import os
for i in audio_file:
  #print(i)
  signal, sr = librosa.load(i)
  mfccs = librosa.feature.mfcc(y=signal, n_mfcc=50, sr=3000)
  plt.figure(figsize=(11, 3))
  a=librosa.display.specshow(mfccs)
  plt.savefig("/content/drive/MyDrive/Heart_ViT_2022/Wave_to_Images/TV/TV_wve_img/"+str(os.path.basename(i).split(".")[0])+".png")
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
#read converted images file based on .png
image_file = glob('../content/drive/MyDrive/D_Thesis/Image_data/TV_wave_to_image/*.png')

# %%
len(image_file)

# %% [markdown]
# **3rd step, Class separated based on given meta data**

# %%
#read csv file for class separation
import pandas as pd
path = "/content/drive/MyDrive/D_Thesis/training_data.csv"
data = pd.read_csv(path)

# %%
data.head(10)
# Out:
#    Patient ID Recording locations:    Age     Sex  Height  Weight  \
# 0        2530          AV+PV+TV+MV  Child  Female    98.0   15.90
# 1        9979          AV+PV+TV+MV  Child  Female   103.0   13.10
# 2        9983          AV+PV+TV+MV  Child    Male   115.0   19.10
# 3       13918          AV+PV+TV+MV  Child    Male    98.0   15.90
# 4       14241          AV+PV+TV+MV  Child    Male    87.0   11.20
# 5       14998          AV+PV+TV+MV  Child    Male     NaN     NaN
# 6       23625          AV+PV+TV+MV  Child  Female    92.0   14.00
# 7       24160          AV+PV+TV+MV  Child  Female    98.0   17.66
# 8       29045          AV+PV+TV+MV  Child  Female    88.0   12.50
# 9       29378                AV+MV  Child  Female    82.0   10.70
#
#    Pregnancy status   Murmur Murmur locations Most audible location  ...  \
# 0             False   Absent              NaN                   NaN  ...
# 1             False  Present      AV+MV+PV+TV                    TV  ...
# ...

# %%
data.drop(['Age','Sex','Height','Weight','Recording locations:','Murmur','Murmur locations','Most audible location','Systolic murmur pitch','Systolic murmur quality','Diastolic murmur timing','Diastolic murmur shape','Diastolic murmur grading','Diastolic murmur pitch','Diastolic murmur quality','Campaign','Additional ID','Systolic murmur timing','Systolic murmur shape','Systolic murmur grading','Pregnancy status'],axis=1,inplace=True)

# %%
data
# Out:
#      Patient ID   Outcome
# 0          2530  Abnormal
# 1          9979  Abnormal
# 2          9983  Abnormal
# 3         13918  Abnormal
# 4         14241  Abnormal
# ..          ...       ...
# 937       85340    Normal
# 938       85341    Normal
# 939       85343  Abnormal
# 940       85345    Normal
# 941       85349    Normal
#
# [942 rows x 2 columns]

# %%
#leveling
data.Outcome[data.Outcome == 'Normal'] = 0
data.Outcome[data.Outcome == 'Abnormal'] = 1
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
data
# Out:
#      Patient ID Outcome
# 0          2530       1
# 1          9979       1
# 2          9983       1
# 3         13918       1
# 4         14241       1
# ..          ...     ...
# 937       85340       0
# 938       85341       0
# 939       85343       1
# 940       85345       0
# 941       85349       0
#
# [942 rows x 2 columns]

# %%
print(data["Patient ID"])
# Out:
# 0       2530
# 1       9979
# 2       9983
# 3      13918
# 4      14241
#        ...
# 937    85340
# 938    85341
# 939    85343
# 940    85345
# 941    85349
# Name: Patient ID, Length: 942, dtype: int64

# %%
print(data["Outcome"])
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 937    0
# 938    0
# 939    1
# 940    0
# 941    0
# Name: Outcome, Length: 942, dtype: object

# %%
data['Outcome'] = data['Outcome'].astype(int)

# %%
print(data["Outcome"])
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 937    0
# 938    0
# 939    1
# 940    0
# 941    0
# Name: Outcome, Length: 942, dtype: int64

# %%
data.rename(columns = {'Patient ID':'P_ID'}, inplace = True)

# %%
#1. AV images class separation

# %%
#audio_file = glob('../content/drive/MyDrive/unzip/AV/*.wav')
image_file = glob('../content/drive/MyDrive/D_Thesis/Img_to_wve_updte/AV_wve_img/*.png')

# %%
import shutil

# %%
import os.path

# %%
for j in image_file:
  basename=str(os.path.basename(j).split("_")[0])
  #print(basename)
  a=int(basename)
  for i in range(942):
    if(a==data.P_ID[i]):
      if(data.Outcome[i]==1):
        print("Abnormal")
        #src_path = r"/content/drive/MyDrive/audio/img/13918_AV.png"
        dst_path = r"/content/drive/MyDrive/D_Thesis/Img_to_wve_updte/AV_wve_img/Abnormal"
        shutil.move(j, dst_path)
        break
      else:
        #src_path = r"/content/drive/MyDrive/audio/img/spe.png"
        dst_path = r"/content/drive/MyDrive/D_Thesis/Img_to_wve_updte/AV_wve_img/Normal"
        shutil.move(j, dst_path)
        print("Normal")
        break
        


  #print(a)

  #print(j)
# Out:
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Normal
# Abnormal
# Abnormal
# Abnormal
# Normal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Normal
# Abnormal
# Normal
# Abnormal
# Abnormal
# Normal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Normal
# Abnormal
# Abnormal
# Normal
# Abnormal
# Normal
# Normal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Normal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Normal
# Normal
# Abnormal
# Abnormal
# Normal
# Abnormal
# Abnormal
# Abnormal
# Normal
# Normal
# Abnormal
# Normal
# Normal
# Normal
# Normal
# Normal
# Abnormal
# Normal
# Normal
# Abnormal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Abnormal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# ...

# %%
#count AV_Abnormal images
#audio_file = glob('../content/drive/MyDrive/unzip/AV/*.wav')
image_file = glob('../content/drive/MyDrive/D_Thesis/Img_to_wve_updte/AV_wve_img/Abnormal/*.png')

# %%
len(image_file)
# Out:
# 401

# %%
#count AV_normal images
#audio_file = glob('../content/drive/MyDrive/unzip/AV/*.wav')
image_file = glob('../content/drive/MyDrive/D_Thesis/Img_to_wve_updte/AV_wve_img/Normal/*.png')

# %%
len(image_file)
# Out:
# 399

# %%
#2. MV images class separation

# %%
#audio_file = glob('../content/drive/MyDrive/unzip/AV/*.wav')
image_file = glob('../content/drive/MyDrive/D_Thesis/Image_data/MV_wave_to_image/*.png')

# %%
for j in image_file:
  basename=str(os.path.basename(j).split("_")[0])
  #print(basename)
  a=int(basename)
  for i in range(942):
    if(a==data.P_ID[i]):
      if(data.Outcome[i]==1):
        print("Abnormal")
        #src_path = r"/content/drive/MyDrive/audio/img/13918_AV.png"
        dst_path = r"/content/drive/MyDrive/D_Thesis/Image_data/MV_wave_to_image/Abnormal"
        shutil.move(j, dst_path)
        break
      else:
        #src_path = r"/content/drive/MyDrive/audio/img/spe.png"
        dst_path = r"/content/drive/MyDrive/D_Thesis/Image_data/MV_wave_to_image/Normal"
        shutil.move(j, dst_path)
        print("Normal")
        break
        


  #print(a)

  #print(j)
# Out:
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Normal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Normal
# Normal
# Abnormal
# Normal
# Abnormal
# Abnormal
# Normal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Normal
# Abnormal
# Abnormal
# Normal
# Abnormal
# Normal
# Abnormal
# Normal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Normal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Normal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Normal
# Abnormal
# Normal
# Abnormal
# Abnormal
# Normal
# Abnormal
# Abnormal
# Abnormal
# Normal
# Normal
# Abnormal
# Normal
# Abnormal
# Normal
# Normal
# Normal
# Normal
# Abnormal
# Abnormal
# Normal
# Normal
# Normal
# Normal
# Normal
# Abnormal
# ...

# %%
#count MV_Abnormal
#audio_file = glob('../content/drive/MyDrive/unzip/AV/*.wav')
image_file = glob('../content/drive/MyDrive/D_Thesis/Image_data/MV_wave_to_image/Abnormal/*.png')

# %%
len(image_file)
# Out:
# 432

# %%
#count MV_Normal
#audio_file = glob('../content/drive/MyDrive/unzip/AV/*.wav')
image_file = glob('../content/drive/MyDrive/D_Thesis/Image_data/MV_wave_to_image/Normal/*.png')

# %%
len(image_file)
# Out:
# 429

# %%
#3. PV images class separation

# %%
#audio_file = glob('../content/drive/MyDrive/unzip/AV/*.wav')
image_file = glob('../content/drive/MyDrive/D_Thesis/Image_data/PV_wave_to_image/*.png')

# %%
for j in image_file:
  basename=str(os.path.basename(j).split("_")[0])
  #print(basename)
  a=int(basename)
  for i in range(942):
    if(a==data.P_ID[i]):
      if(data.Outcome[i]==1):
        print("Abnormal")
        #src_path = r"/content/drive/MyDrive/audio/img/13918_AV.png"
        dst_path = r"/content/drive/MyDrive/D_Thesis/Image_data/PV_wave_to_image/Abnormal"
        shutil.move(j, dst_path)
        break
      else:
        #src_path = r"/content/drive/MyDrive/audio/img/spe.png"
        dst_path = r"/content/drive/MyDrive/D_Thesis/Image_data/PV_wave_to_image/Normal"
        shutil.move(j, dst_path)
        print("Normal")
        break
        


  #print(a)

  #print(j)
# Out:
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Normal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Normal
# Normal
# Abnormal
# Normal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Normal
# Abnormal
# Abnormal
# Normal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Normal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Normal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Normal
# Abnormal
# Normal
# Abnormal
# Abnormal
# Normal
# Normal
# Normal
# Normal
# Abnormal
# Normal
# Normal
# Abnormal
# Normal
# Normal
# Abnormal
# Abnormal
# Normal
# Normal
# Abnormal
# Normal
# Normal
# Abnormal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Abnormal
# Normal
# Normal
# Normal
# Abnormal
# Normal
# Normal
# Normal
# Normal
# Abnormal
# Normal
# ...

# %%
#count PV_Abnormal images
#audio_file = glob('../content/drive/MyDrive/unzip/AV/*.wav')
image_file = glob('../content/drive/MyDrive/D_Thesis/Image_data/PV_wave_to_image/Abnormal/*.png')

# %%
len(image_file)
# Out:
# 355

# %%
#count PV normal images
#audio_file = glob('../content/drive/MyDrive/unzip/AV/*.wav')
image_file = glob('../content/drive/MyDrive/D_Thesis/Image_data/PV_wave_to_image/Normal/*.png')

# %%
len(image_file)
# Out:
# 411

# %%
#TV images class separation

# %%
#audio_file = glob('../content/drive/MyDrive/unzip/AV/*.wav')
image_file = glob('../content/drive/MyDrive/Heart_ViT_2022/Wave_to_Images/TV/TV_wve_img/*.png')

# %%
len(image_file)
# Out:
# 732

# %%
# !mkdir "/content/drive/MyDrive/Heart_ViT_2022/Wave_to_Images/TV/TV_wve_img/Abnormal"
# !mkdir "/content/drive/MyDrive/Heart_ViT_2022/Wave_to_Images/TV/TV_wve_img/Normal"

# %%
import shutil

# %%
for j in image_file:
  basename=str(os.path.basename(j).split("_")[0])
  #print(basename)
  a=int(basename)
  for i in range(942):
    if(a==data.P_ID[i]):
      if(data.Outcome[i]==1):
        print("Abnormal")
        #src_path = r"/content/drive/MyDrive/audio/img/13918_AV.png"
        dst_path = r"/content/drive/MyDrive/Heart_ViT_2022/Wave_to_Images/TV/TV_wve_img/Abnormal"
        shutil.move(j, dst_path)
        break
      else:
        #src_path = r"/content/drive/MyDrive/audio/img/spe.png"
        dst_path = r"/content/drive/MyDrive/Heart_ViT_2022/Wave_to_Images/TV/TV_wve_img/Normal"
        shutil.move(j, dst_path)
        print("Normal")
        break
        


  #print(a)

  #print(j)
# Out:
# Normal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Normal
# Normal
# Abnormal
# Normal
# Normal
# Normal
# Abnormal
# Abnormal
# Abnormal
# Normal
# Normal
# Normal
# Normal
# Abnormal
# Normal
# Abnormal
# Normal
# Normal
# Normal
# Normal
# Abnormal
# Abnormal
# Normal
# Abnormal
# Normal
# Normal
# Normal
# Abnormal
# Normal
# Normal
# Abnormal
# Normal
# Normal
# Abnormal
# Abnormal
# Normal
# Abnormal
# Normal
# Normal
# Normal
# Normal
# Abnormal
# Abnormal
# Abnormal
# Normal
# Normal
# Normal
# Normal
# Normal
# Abnormal
# Normal
# Abnormal
# Normal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Normal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Normal
# Abnormal
# Abnormal
# Normal
# Abnormal
# Abnormal
# Abnormal
# Normal
# Abnormal
# Normal
# Abnormal
# Normal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Abnormal
# Normal
# Normal
# Abnormal
# Abnormal
# Abnormal
# ...

# %%
#count TV_Abnormal images
from glob import glob
#audio_file = glob('../content/drive/MyDrive/unzip/AV/*.wav')
image_file = glob('../content/drive/MyDrive/Heart_ViT_2022/Wave_to_Images/TV/Abnormal/*.png')

# %%
len(image_file)
# Out:
# 339

# %%
#count TV_Normal images
#audio_file = glob('../content/drive/MyDrive/unzip/AV/*.wav')
image_file = glob('../content/drive/MyDrive/Heart_ViT_2022/Wave_to_Images/TV/Normal/*.png')

# %%
len(image_file)
# Out:
# 393

# %%
from IPython.display import display, Image
display(Image(filename='/content/drive/MyDrive/Heart_ViT_2022/Wave_to_Images/TV/Abnormal/13918_TV.png'))

# %% [markdown]
# **4th steps, Implementation using Vit(Vision transformer)**

# %% [markdown]
# 1. **For AV** **location**

# %%
from glob import glob
abnormal = glob('../content/drive/MyDrive/Heart_ViT_2022/Wave_to_Images/AV/AV_wve_img/Abnormal/*.png')

# %%
len(abnormal)
# Out:
# 401

# %%
# !mkdir "/content/drive/MyDrive/Heart_ViT_2022/crooped_image/AV/Normal"

# %%
# crop AV_Abnormal image
from PIL import Image
import os
for i  in abnormal: 
  im = Image.open(i)
  im1 = im.crop(((99,26, 713, 189)))
  im1 = im1.save("/content/drive/MyDrive/D_Thesis/Image_data/AV_crop_image/Abnormal/"+str(os.path.basename(i).split(".")[0])+".png")
  #("/content/drive/MyDrive/D_Thesis/Image_data/AV_wave_to_image/"+str(os.path.basename(i).split(".")[0])+".png")

# %%
abnormal_len=glob('../content/drive/MyDrive/Heart_ViT_2022/crooped_image/AV/Abnormal/*.png')

# %%
len(abnormal_len)
# Out:
# 401

# %%
#cropped AV_normal images

# %%
normal = glob('../content/drive/MyDrive/Heart_ViT_2022/crooped_image/AV/Normal/*.png')

# %%
len(normal)
# Out:
# 399

# %%
from PIL import Image
import os
for i  in normal: 
  im = Image.open(i)
  im1 = im.crop(((99, 26, 713, 189)))
  im1 = im1.save("/content/drive/MyDrive/Heart_ViT_2022/crooped_image/AV/Normal/"+str(os.path.basename(i).split(".")[0])+".png")
  #("/content/drive/MyDrive/D_Thesis/Image_data/AV_wave_to_image/"+str(os.path.basename(i).split(".")[0])+".png")

# %%
normal_len = glob('../content/drive/MyDrive/Heart_ViT_2022/crooped_image/AV/Normal/*.png')

# %%
len(normal_len)
# Out:
# 399

# %%
#Vit(Vition transformer)_AV

# %%
# !pip install -U tensorflow-addons
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.1 MB 5.0 MB/s
# ...

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_addons as tfa

# %%
#Split images dataset into train_test_validation
import glob
normal = glob.glob('/content/drive/MyDrive/Heart_ViT_2022/crooped_image/AV/Normal/*.*')
abnormal = glob.glob('/content/drive/MyDrive/Heart_ViT_2022/crooped_image/AV/Abnormal/*.*')

data = []
labels = []

for i in normal:   
    image=tf.keras.preprocessing.image.load_img(i, color_mode='rgb', 
    target_size= (280,280))
    image=np.array(image)
    data.append(image)
    labels.append(0)
for i in abnormal:   
    image=tf.keras.preprocessing.image.load_img(i, color_mode='rgb', 
    target_size= (280,280))
    image=np.array(image)
    data.append(image)
    labels.append(1)


data = np.array(data)
labels = np.array(labels)

from sklearn.model_selection import train_test_split
X_train, X_test, ytrain, ytest = train_test_split(data, labels, test_size=0.2,
                                                random_state=42)

# %%
X_train.shape
# Out:
# (640, 280, 280, 3)

# %%
ytrain.shape
# Out:
# (640,)

# %%
num_classes = 2
input_shape = (280, 280, 3)

#(x_train, y_train), (x_test, y_test) = keras.datasets.cifar100.load_data()

print(f"x_train shape: {X_train.shape} - ytrain shape: {ytrain.shape}")
print(f"x_test shape: {X_test.shape} - ytest shape: {ytest.shape}")
# Out:
# x_train shape: (640, 280, 280, 3) - ytrain shape: (640,)
# x_test shape: (160, 280, 280, 3) - ytest shape: (160,)

# %%
#configure hyper parameter tuning
learning_rate = 0.001
weight_decay = 0.0001
batch_size = 256
num_epochs = 100
image_size = 72  # We'll resize input images to this size
patch_size = 6  # Size of the patches to be extract from the input images
num_patches = (image_size // patch_size) ** 2
projection_dim = 64
num_heads = 4
transformer_units = [
    projection_dim * 2,
    projection_dim,
]  # Size of the transformer layers
transformer_layers = 8
mlp_head_units = [2048, 1024]  # Size of the dense layers of the final classifier

# %%
#data augmentation
data_augmentation = keras.Sequential(
    [
        layers.Normalization(),
        layers.Resizing(image_size, image_size),
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(factor=0.02),
        layers.RandomZoom(
            height_factor=0.2, width_factor=0.2
        ),
    ],
    name="data_augmentation",
)
# Compute the mean and the variance of the training data for normalization.
data_augmentation.layers[0].adapt(X_train)

# %%
#multilayer perceptron (MLP)
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x

# %%
#patch creation as a layer
class Patches(layers.Layer):
    def __init__(self, patch_size):
        super(Patches, self).__init__()
        self.patch_size = patch_size

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID",
        )
        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches, [batch_size, -1, patch_dims])
        return patches

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(4, 4))
image = X_train[np.random.choice(range(X_train.shape[0]))]
plt.imshow(image.astype("uint8"))
plt.axis("off")

resized_image = tf.image.resize(
    tf.convert_to_tensor([image]), size=(image_size, image_size)
)
patches = Patches(patch_size)(resized_image)
print(f"Image size: {image_size} X {image_size}")
print(f"Patch size: {patch_size} X {patch_size}")
print(f"Patches per image: {patches.shape[1]}")
print(f"Elements per patch: {patches.shape[-1]}")
A
n = int(np.sqrt(patches.shape[1]))
plt.figure(figsize=(4, 4))
for i, patch in enumerate(patches[0]):
    ax = plt.subplot(n, n, i + 1)
    patch_img = tf.reshape(patch, (patch_size, patch_size, 3))
    plt.imshow(patch_img.numpy().astype("uint8"))
    plt.axis("off")
# Out:
# Image size: 72 X 72
# Patch size: 6 X 6
# Patches per image: 144
# Elements per patch: 108

# %%
#patch encoding layer
class PatchEncoder(layers.Layer):
    def __init__(self, num_patches, projection_dim):
        super(PatchEncoder, self).__init__()
        self.num_patches = num_patches
        self.projection = layers.Dense(units=projection_dim)
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )

    def call(self, patch):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        encoded = self.projection(patch) + self.position_embedding(positions)
        return encoded

# %%
#Build ViT model
def create_vit_classifier():
    inputs = layers.Input(shape=input_shape)
    # Augment data.
    augmented = data_augmentation(inputs)
    # Create patches.
    patches = Patches(patch_size)(augmented)
    # Encode patches.
    encoded_patches = PatchEncoder(num_patches, projection_dim)(patches)

    # Create multiple layers of the Transformer block.
    for _ in range(transformer_layers):
        # Layer normalization 1.
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        # Create a multi-head attention layer.
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=projection_dim, dropout=0.1
        )(x1, x1)
        # Skip connection 1.
        x2 = layers.Add()([attention_output, encoded_patches])
        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        # MLP.
        x3 = mlp(x3, hidden_units=transformer_units, dropout_rate=0.1)
        # Skip connection 2.
        encoded_patches = layers.Add()([x3, x2])

    # Create a [batch_size, projection_dim] tensor.
    representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
    representation = layers.Flatten()(representation)
    representation = layers.Dropout(0.5)(representation)
    # Add MLP.
    features = mlp(representation, hidden_units=mlp_head_units, dropout_rate=0.5)
    # Classify outputs.
    logits = layers.Dense(num_classes)(features)
    # Create the Keras model.
    model = keras.Model(inputs=inputs, outputs=logits)
    return model

# %%
#Compile, train, and evaluate the mode
def run_experiment(model):
    optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

    model.compile(
        optimizer=optimizer,
        loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=[
            keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
            keras.metrics.SparseTopKCategoricalAccuracy(5, name="top-5-accuracy"),
        ],
    )

#checkpoint path
    checkpoint_filepath = "/tmp/checkpoint"
    checkpoint_callback = keras.callbacks.ModelCheckpoint(
        checkpoint_filepath,
        monitor="val_accuracy",
        save_best_only=True,
        save_weights_only=True,
    )

    history = model.fit(
        x=X_train,
        y=ytrain,
        batch_size=batch_size,
        epochs=num_epochs,
        validation_split=0.1,
        callbacks=[checkpoint_callback],
    )

    model.load_weights(checkpoint_filepath)
    _, accuracy, top_5_accuracy = model.evaluate(X_test, ytest)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")
    print(f"Test top 5 accuracy: {round(top_5_accuracy * 100, 2)}%")

    return history


vit_classifier = create_vit_classifier()
history = run_experiment(vit_classifier)
# Out:
# Epoch 1/100
# 3/3 [==============================] - 17s 1s/step - loss: 3.1419 - accuracy: 0.5382 - top-5-accuracy: 1.0000 - val_loss: 26.3050 - val_accuracy: 0.4688 - val_top-5-accuracy: 1.0000
# Epoch 2/100
# 3/3 [==============================] - 2s 769ms/step - loss: 13.1103 - accuracy: 0.5017 - top-5-accuracy: 1.0000 - val_loss: 4.7288 - val_accuracy: 0.5312 - val_top-5-accuracy: 1.0000
# Epoch 3/100
# 3/3 [==============================] - 1s 286ms/step - loss: 5.1227 - accuracy: 0.5069 - top-5-accuracy: 1.0000 - val_loss: 2.8392 - val_accuracy: 0.4688 - val_top-5-accuracy: 1.0000
# Epoch 4/100
# 3/3 [==============================] - 1s 283ms/step - loss: 2.1601 - accuracy: 0.4948 - top-5-accuracy: 1.0000 - val_loss: 1.9538 - val_accuracy: 0.3906 - val_top-5-accuracy: 1.0000
# Epoch 5/100
# 3/3 [==============================] - 2s 694ms/step - loss: 1.8175 - accuracy: 0.4740 - top-5-accuracy: 1.0000 - val_loss: 0.6726 - val_accuracy: 0.5469 - val_top-5-accuracy: 1.0000
# ...

# %% [markdown]
# 2. **For MV location**

# %%
from glob import glob
abnormal = glob('../content/drive/MyDrive/Heart_ViT_2022/Wave_to_Images/MV/MV_wve_img/Abnormal/*.png')

# %%
len(abnormal)
# Out:
# 432

# %%
# !mkdir "/content/drive/MyDrive/Heart_ViT_2022/crooped_image/MV/Abnormal"
#!rm -r "/content/drive/MyDrive/Heart_ViT_2022/crooped_image/MV/Abnormal"

# %%
# crop image
from PIL import Image
import os
for i  in abnormal: 
  im = Image.open(i)
  im1 = im.crop(((99, 26, 713, 189)))
  im1 = im1.save("/content/drive/MyDrive/Heart_ViT_2022/crooped_image/MV/Abnormal/"+str(os.path.basename(i).split(".")[0])+".png")
  #("/content/drive/MyDrive/D_Thesis/Image_data/AV_wave_to_image/"+str(os.path.basename(i).split(".")[0])+".png")

# %%
abnormal = glob('../content/drive/MyDrive/Heart_ViT_2022/crooped_image/MV/Abnormal/*.png')

# %%
len(abnormal)
# Out:
# 432

# %%
# !mkdir "/content/drive/MyDrive/Heart_ViT_2022/crooped_image/MV/Normal/"

# %%
from glob import glob
normal = glob('../content/drive/MyDrive/Heart_ViT_2022/crooped_image/MV/Normal/*.png')

# %%
len(normal)
# Out:
# 429

# %%
# crop image
from PIL import Image
import os
for i  in normal: 
  im = Image.open(i)
  im1 = im.crop(((99, 26, 713, 189)))
  im1 = im1.save("/content/drive/MyDrive/Heart_ViT_2022/crooped_image/MV/Normal/"+str(os.path.basename(i).split(".")[0])+".png")
  #("/content/drive/MyDrive/D_Thesis/Image_data/AV_wave_to_image/"+str(os.path.basename(i).split(".")[0])+".png")

# %%
normal = glob('../content/drive/MyDrive/Heart_ViT_2022/crooped_image/MV/Normal/*.png')

# %%
len(normal)
# Out:
# 429

# %%
#ViT (Vision Transformer) MV

# %%
# !pip install -U tensorflow-addons
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_addons as tfa

# %%
#Split images dataset into train_test_validation
import glob
normal = glob.glob('/content/drive/MyDrive/Heart_ViT_2022/crooped_image/MV/Normal/*.*')
abnormal = glob.glob('/content/drive/MyDrive/Heart_ViT_2022/crooped_image/MV/Abnormal/*.*')

data = []
labels = []

for i in normal:   
    image=tf.keras.preprocessing.image.load_img(i, color_mode='rgb', 
    target_size= (280,280))
    image=np.array(image)
    data.append(image)
    labels.append(0)
for i in abnormal:   
    image=tf.keras.preprocessing.image.load_img(i, color_mode='rgb', 
    target_size= (280,280))
    image=np.array(image)
    data.append(image)
    labels.append(1)


data = np.array(data)
labels = np.array(labels)

from sklearn.model_selection import train_test_split
X_train, X_test, ytrain, ytest = train_test_split(data, labels, test_size=0.2,
                                                random_state=42)

# %%
X_train.shape
# Out:
# (688, 280, 280, 3)

# %%
ytrain.shape
# Out:
# (688,)

# %%
num_classes = 2
input_shape = (280, 280, 3)

#(x_train, y_train), (x_test, y_test) = keras.datasets.cifar100.load_data()

print(f"x_train shape: {X_train.shape} - ytrain shape: {ytrain.shape}")
print(f"x_test shape: {X_test.shape} - ytest shape: {ytest.shape}")
# Out:
# x_train shape: (688, 280, 280, 3) - ytrain shape: (688,)
# x_test shape: (173, 280, 280, 3) - ytest shape: (173,)

# %%
#hyper parameter tuning
learning_rate = 0.001
weight_decay = 0.0001
batch_size = 256
num_epochs = 100
image_size = 72  # We'll resize input images to this size
patch_size = 6  # Size of the patches to be extract from the input images
num_patches = (image_size // patch_size) ** 2
projection_dim = 64
num_heads = 4
transformer_units = [
    projection_dim * 2,
    projection_dim,
]  # Size of the transformer layers
transformer_layers = 8
mlp_head_units = [2048, 1024]  # Size of the dense layers of the final classifier

# %%
#Data augmentation
data_augmentation = keras.Sequential(
    [
        layers.Normalization(),
        layers.Resizing(image_size, image_size),
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(factor=0.02),
        layers.RandomZoom(
            height_factor=0.2, width_factor=0.2
        ),
    ],
    name="data_augmentation",
)
# Compute the mean and the variance of the training data for normalization.
data_augmentation.layers[0].adapt(X_train)

# %%
#multilayer perceptron (MLP)
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x

# %%
#patch creation as a layer
class Patches(layers.Layer):
    def __init__(self, patch_size):
        super(Patches, self).__init__()
        self.patch_size = patch_size

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID",
        )
        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches, [batch_size, -1, patch_dims])
        return patches

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(4, 4))
image = X_train[np.random.choice(range(X_train.shape[0]))]
plt.imshow(image.astype("uint8"))
plt.axis("off")

resized_image = tf.image.resize(
    tf.convert_to_tensor([image]), size=(image_size, image_size)
)
patches = Patches(patch_size)(resized_image)
print(f"Image size: {image_size} X {image_size}")
print(f"Patch size: {patch_size} X {patch_size}")
print(f"Patches per image: {patches.shape[1]}")
print(f"Elements per patch: {patches.shape[-1]}")

n = int(np.sqrt(patches.shape[1]))
plt.figure(figsize=(4, 4))
for i, patch in enumerate(patches[0]):
    ax = plt.subplot(n, n, i + 1)
    patch_img = tf.reshape(patch, (patch_size, patch_size, 3))
    plt.imshow(patch_img.numpy().astype("uint8"))
    plt.axis("off")
# Out:
# Image size: 72 X 72
# Patch size: 6 X 6
# Patches per image: 144
# Elements per patch: 108

# %%
#patch encoding layer
class PatchEncoder(layers.Layer):
    def __init__(self, num_patches, projection_dim):
        super(PatchEncoder, self).__init__()
        self.num_patches = num_patches
        self.projection = layers.Dense(units=projection_dim)
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )

    def call(self, patch):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        encoded = self.projection(patch) + self.position_embedding(positions)
        return encoded

# %%
#build vit model
def create_vit_classifier():
    inputs = layers.Input(shape=input_shape)
    # Augment data.
    augmented = data_augmentation(inputs)
    # Create patches.
    patches = Patches(patch_size)(augmented)
    # Encode patches.
    encoded_patches = PatchEncoder(num_patches, projection_dim)(patches)

    # Create multiple layers of the Transformer block.
    for _ in range(transformer_layers):
        # Layer normalization 1.
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        # Create a multi-head attention layer.
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=projection_dim, dropout=0.1
        )(x1, x1)
        # Skip connection 1.
        x2 = layers.Add()([attention_output, encoded_patches])
        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        # MLP.
        x3 = mlp(x3, hidden_units=transformer_units, dropout_rate=0.1)
        # Skip connection 2.
        encoded_patches = layers.Add()([x3, x2])

    # Create a [batch_size, projection_dim] tensor.
    representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
    representation = layers.Flatten()(representation)
    representation = layers.Dropout(0.5)(representation)
    # Add MLP.
    features = mlp(representation, hidden_units=mlp_head_units, dropout_rate=0.5)
    # Classify outputs.
    logits = layers.Dense(num_classes)(features)
    # Create the Keras model.
    model = keras.Model(inputs=inputs, outputs=logits)
    return model

# %%
#Compile, train, and evaluate the mode
def run_experiment(model):
    optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

    model.compile(
        optimizer=optimizer,
        loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=[
            keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
            keras.metrics.SparseTopKCategoricalAccuracy(5, name="top-5-accuracy"),
        ],
    )

#checkpoint path
    checkpoint_filepath = "/tmp/checkpoint"
    checkpoint_callback = keras.callbacks.ModelCheckpoint(
        checkpoint_filepath,
        monitor="val_accuracy",
        save_best_only=True,
        save_weights_only=True,
    )

    history = model.fit(
        x=X_train,
        y=ytrain,
        batch_size=batch_size,
        epochs=num_epochs,
        validation_split=0.1,
        callbacks=[checkpoint_callback],
    )

    model.load_weights(checkpoint_filepath)
    _, accuracy, top_5_accuracy = model.evaluate(X_test, ytest)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")
    print(f"Test top 5 accuracy: {round(top_5_accuracy * 100, 2)}%")

    return history


vit_classifier = create_vit_classifier()
history = run_experiment(vit_classifier)
# Out:
# Epoch 1/100
# 3/3 [==============================] - 13s 1s/step - loss: 8.7963 - accuracy: 0.4927 - top-5-accuracy: 1.0000 - val_loss: 10.5405 - val_accuracy: 0.4638 - val_top-5-accuracy: 1.0000
# Epoch 2/100
# 3/3 [==============================] - 2s 756ms/step - loss: 5.5812 - accuracy: 0.5153 - top-5-accuracy: 1.0000 - val_loss: 1.7468 - val_accuracy: 0.4783 - val_top-5-accuracy: 1.0000
# Epoch 3/100
# 3/3 [==============================] - 1s 387ms/step - loss: 1.8151 - accuracy: 0.5024 - top-5-accuracy: 1.0000 - val_loss: 2.6406 - val_accuracy: 0.4783 - val_top-5-accuracy: 1.0000
# Epoch 4/100
# 3/3 [==============================] - 2s 717ms/step - loss: 1.8756 - accuracy: 0.4830 - top-5-accuracy: 1.0000 - val_loss: 0.7616 - val_accuracy: 0.5217 - val_top-5-accuracy: 1.0000
# Epoch 5/100
# 3/3 [==============================] - 1s 315ms/step - loss: 1.4574 - accuracy: 0.5008 - top-5-accuracy: 1.0000 - val_loss: 0.9204 - val_accuracy: 0.4348 - val_top-5-accuracy: 1.0000
# ...

# %% [markdown]
# 3. **For PV location**

# %%
from glob import glob
abnormal = glob('../content/drive/MyDrive/Heart_ViT_2022/Wave_to_Images/PV/PV_wve_img/Abnormal/*.png')

# %%
len(abnormal)
# Out:
# 355

# %%
# !mkdir "/content/drive/MyDrive/Heart_ViT_2022/crooped_image/PV/Abnormal"

# %%
# crop image
from PIL import Image
import os
for i  in abnormal: 
  im = Image.open(i)
  im1 = im.crop(((99, 26, 713, 189)))
  im1 = im1.save("/content/drive/MyDrive/Heart_ViT_2022/crooped_image/PV/Abnormal/"+str(os.path.basename(i).split(".")[0])+".png")
  #("/content/drive/MyDrive/D_Thesis/Image_data/AV_wave_to_image/"+str(os.path.basename(i).split(".")[0])+".png")

# %%
abnormal_len=glob('../content/drive/MyDrive/Heart_ViT_2022/crooped_image/PV/Abnormal/*.png')

# %%
len(abnormal_len)
# Out:
# 355

# %%
normal = glob('../content/drive/MyDrive/Heart_ViT_2022/Wave_to_Images/PV/PV_wve_img/Normal/*.png')

# %%
len(normal)
# Out:
# 411

# %%
# !mkdir "/content/drive/MyDrive/Heart_ViT_2022/crooped_image/PV/Normal"

# %%
# crop image
for i  in normal: 
  im = Image.open(i)
  im1 = im.crop(((99, 26, 713, 189)))
  im1 = im1.save("/content/drive/MyDrive/Heart_ViT_2022/crooped_image/PV/Normal/"+str(os.path.basename(i).split(".")[0])+".png")
  #("/content/drive/MyDrive/D_Thesis/Image_data/AV_wave_to_image/"+str(os.path.basename(i).split(".")[0])+".png")

# %%
normal_len = glob('../content/drive/MyDrive/Heart_ViT_2022/crooped_image/PV/Normal/*.png')

# %%
len(normal_len)
# Out:
# 411

# %%
#ViT(Vision transformer)
# !pip install -U tensorflow-addons
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_addons as tfa

# %%
#split images dataset int train_test_validation
import glob
normal = glob.glob('/content/drive/MyDrive/Heart_ViT_2022/crooped_image/PV/Normal/*.*')
abnormal = glob.glob('/content/drive/MyDrive/Heart_ViT_2022/crooped_image/PV/Abnormal/*.*')

data = []
labels = []

for i in normal:   
    image=tf.keras.preprocessing.image.load_img(i, color_mode='rgb', 
    target_size= (280,280))
    image=np.array(image)
    data.append(image)
    labels.append(0)
for i in abnormal:   
    image=tf.keras.preprocessing.image.load_img(i, color_mode='rgb', 
    target_size= (280,280))
    image=np.array(image)
    data.append(image)
    labels.append(1)


data = np.array(data)
labels = np.array(labels)

from sklearn.model_selection import train_test_split
X_train, X_test, ytrain, ytest = train_test_split(data, labels, test_size=0.2,
                                                random_state=42)

# %%
X_train.shape
# Out:
# (612, 280, 280, 3)

# %%
ytrain.shape
# Out:
# (612,)

# %%
num_classes = 2
input_shape = (280, 280, 3)

#(x_train, y_train), (x_test, y_test) = keras.datasets.cifar100.load_data()

print(f"x_train shape: {X_train.shape} - ytrain shape: {ytrain.shape}")
print(f"x_test shape: {X_test.shape} - ytest shape: {ytest.shape}")
# Out:
# x_train shape: (612, 280, 280, 3) - ytrain shape: (612,)
# x_test shape: (154, 280, 280, 3) - ytest shape: (154,)

# %%
#hyper parameter tuning
learning_rate = 0.001
weight_decay = 0.0001
batch_size = 256
num_epochs = 100
image_size = 72  # We'll resize input images to this size
patch_size = 6  # Size of the patches to be extract from the input images
num_patches = (image_size // patch_size) ** 2
projection_dim = 64
num_heads = 4
transformer_units = [
    projection_dim * 2,
    projection_dim,
]  # Size of the transformer layers
transformer_layers = 8
mlp_head_units = [2048, 1024]  # Size of the dense layers of the final classifier

# %%
#data augmentation
data_augmentation = keras.Sequential(
    [
        layers.Normalization(),
        layers.Resizing(image_size, image_size),
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(factor=0.02),
        layers.RandomZoom(
            height_factor=0.2, width_factor=0.2
        ),
    ],
    name="data_augmentation",
)
# Compute the mean and the variance of the training data for normalization.
data_augmentation.layers[0].adapt(X_train)

# %%
#multilayer perceptron (MLP)
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x

# %%
#patch creation as a layer
class Patches(layers.Layer):
    def __init__(self, patch_size):
        super(Patches, self).__init__()
        self.patch_size = patch_size

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID",
        )
        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches, [batch_size, -1, patch_dims])
        return patches

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(4, 4))
image = X_train[np.random.choice(range(X_train.shape[0]))]
plt.imshow(image.astype("uint8"))
plt.axis("off")

resized_image = tf.image.resize(
    tf.convert_to_tensor([image]), size=(image_size, image_size)
)
patches = Patches(patch_size)(resized_image)
print(f"Image size: {image_size} X {image_size}")
print(f"Patch size: {patch_size} X {patch_size}")
print(f"Patches per image: {patches.shape[1]}")
print(f"Elements per patch: {patches.shape[-1]}")

n = int(np.sqrt(patches.shape[1]))
plt.figure(figsize=(4, 4))
for i, patch in enumerate(patches[0]):
    ax = plt.subplot(n, n, i + 1)
    patch_img = tf.reshape(patch, (patch_size, patch_size, 3))
    plt.imshow(patch_img.numpy().astype("uint8"))
    plt.axis("off")
# Out:
# Image size: 72 X 72
# Patch size: 6 X 6
# Patches per image: 144
# Elements per patch: 108

# %%
class PatchEncoder(layers.Layer):
    def __init__(self, num_patches, projection_dim):
        super(PatchEncoder, self).__init__()
        self.num_patches = num_patches
        self.projection = layers.Dense(units=projection_dim)
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )

    def call(self, patch):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        encoded = self.projection(patch) + self.position_embedding(positions)
        return encoded

# %%
#build ViT
def create_vit_classifier():
    inputs = layers.Input(shape=input_shape)
    # Augment data.
    augmented = data_augmentation(inputs)
    # Create patches.
    patches = Patches(patch_size)(augmented)
    # Encode patches.
    encoded_patches = PatchEncoder(num_patches, projection_dim)(patches)

    # Create multiple layers of the Transformer block.
    for _ in range(transformer_layers):
        # Layer normalization 1.
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        # Create a multi-head attention layer.
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=projection_dim, dropout=0.1
        )(x1, x1)
        # Skip connection 1.
        x2 = layers.Add()([attention_output, encoded_patches])
        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        # MLP.
        x3 = mlp(x3, hidden_units=transformer_units, dropout_rate=0.1)
        # Skip connection 2.
        encoded_patches = layers.Add()([x3, x2])

    # Create a [batch_size, projection_dim] tensor.
    representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
    representation = layers.Flatten()(representation)
    representation = layers.Dropout(0.5)(representation)
    # Add MLP.
    features = mlp(representation, hidden_units=mlp_head_units, dropout_rate=0.5)
    # Classify outputs.
    logits = layers.Dense(num_classes)(features)
    # Create the Keras model.
    model = keras.Model(inputs=inputs, outputs=logits)
    return model

# %%
#Compile, train, and evaluate the mode
def run_experiment(model):
    optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

    model.compile(
        optimizer=optimizer,
        loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=[
            keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
            keras.metrics.SparseTopKCategoricalAccuracy(5, name="top-5-accuracy"),
        ],
    )

#checkpoint path
    checkpoint_filepath = "/tmp/checkpoint"
    checkpoint_callback = keras.callbacks.ModelCheckpoint(
        checkpoint_filepath,
        monitor="val_accuracy",
        save_best_only=True,
        save_weights_only=True,
    )

    history = model.fit(
        x=X_train,
        y=ytrain,
        batch_size=batch_size,
        epochs=num_epochs,
        validation_split=0.1,
        callbacks=[checkpoint_callback],
    )

    model.load_weights(checkpoint_filepath)
    _, accuracy, top_5_accuracy = model.evaluate(X_test, ytest)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")
    print(f"Test top 5 accuracy: {round(top_5_accuracy * 100, 2)}%")

    return history


vit_classifier = create_vit_classifier()
history = run_experiment(vit_classifier)
# Out:
# Epoch 1/100
# 3/3 [==============================] - 13s 1s/step - loss: 13.2961 - accuracy: 0.5055 - top-5-accuracy: 1.0000 - val_loss: 1.3769 - val_accuracy: 0.4516 - val_top-5-accuracy: 1.0000
# Epoch 2/100
# 3/3 [==============================] - 1s 264ms/step - loss: 3.7971 - accuracy: 0.5291 - top-5-accuracy: 1.0000 - val_loss: 4.4446 - val_accuracy: 0.4516 - val_top-5-accuracy: 1.0000
# Epoch 3/100
# 3/3 [==============================] - 2s 660ms/step - loss: 2.8798 - accuracy: 0.5000 - top-5-accuracy: 1.0000 - val_loss: 1.8339 - val_accuracy: 0.5484 - val_top-5-accuracy: 1.0000
# Epoch 4/100
# 3/3 [==============================] - 1s 263ms/step - loss: 2.2986 - accuracy: 0.5291 - top-5-accuracy: 1.0000 - val_loss: 1.1067 - val_accuracy: 0.4677 - val_top-5-accuracy: 1.0000
# Epoch 5/100
# 3/3 [==============================] - 1s 263ms/step - loss: 2.0233 - accuracy: 0.4836 - top-5-accuracy: 1.0000 - val_loss: 1.2114 - val_accuracy: 0.4516 - val_top-5-accuracy: 1.0000
# ...

# %% [markdown]
# 4. **For TV location**

# %%
from glob import glob
abnormal = glob('../content/drive/MyDrive/Heart_ViT_2022/Wave_to_Images/TV/TV_wve_img/Abnormal/*.png')

# %%
len(abnormal)
# Out:
# 339

# %%
# !mkdir "/content/drive/MyDrive/Heart_ViT_2022/crooped_image/TV/Abnormal"

# %%
# crop image
from PIL import Image
import os
for i  in abnormal: 
  im = Image.open(i)
  im1 = im.crop(((99, 26, 713, 189)))
  im1 = im1.save("/content/drive/MyDrive/Heart_ViT_2022/crooped_image/TV/Abnormal/"+str(os.path.basename(i).split(".")[0])+".png")
  #("/content/drive/MyDrive/D_Thesis/Image_data/AV_wave_to_image/"+str(os.path.basename(i).split(".")[0])+".png")

# %%
from glob import glob
abnormal_len=glob('../content/drive/MyDrive/Heart_ViT_2022/crooped_image/TV/Abnormal/*.png')

# %%
len(abnormal_len)
# Out:
# 339

# %%
normal = glob('../content/drive/MyDrive/Heart_ViT_2022/Wave_to_Images/TV/TV_wve_img/Normal/*.png')

# %%
len(normal)
# Out:
# 393

# %%
# !mkdir "/content/drive/MyDrive/Heart_ViT_2022/crooped_image/TV/Normal"

# %%
# crop image
for i  in normal: 
  im = Image.open(i)
  im1 = im.crop(((99, 26, 713, 189)))
  im1 = im1.save("/content/drive/MyDrive/Heart_ViT_2022/crooped_image/TV/Normal/"+str(os.path.basename(i).split(".")[0])+".png")
  #("/content/drive/MyDrive/D_Thesis/Image_data/AV_wave_to_image/"+str(os.path.basename(i).split(".")[0])+".png")

# %%
normal_len = glob('../content/drive/MyDrive/Heart_ViT_2022/crooped_image/TV/Normal/*.png')

# %%
len(normal_len)
# Out:
# 393

# %%
#ViT(Vision Transformer)

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_addons as tfa

# %%
#split images dataset int train_test_validation
import glob
normal = glob.glob('/content/drive/MyDrive/Heart_ViT_2022/crooped_image/TV/Normal/*.*')
abnormal = glob.glob('/content/drive/MyDrive/Heart_ViT_2022/crooped_image/TV/Abnormal/*.*')

data = []
labels = []

for i in normal:   
    image=tf.keras.preprocessing.image.load_img(i, color_mode='rgb', 
    target_size= (280,280))
    image=np.array(image)
    data.append(image)
    labels.append(0)
for i in abnormal:   
    image=tf.keras.preprocessing.image.load_img(i, color_mode='rgb', 
    target_size= (280,280))
    image=np.array(image)
    data.append(image)
    labels.append(1)


data = np.array(data)
labels = np.array(labels)

from sklearn.model_selection import train_test_split
X_train, X_test, ytrain, ytest = train_test_split(data, labels, test_size=0.2,
                                                random_state=42)

# %%
num_classes = 2
input_shape = (280, 280, 3)

# %%
learning_rate = 0.001
weight_decay = 0.0001
batch_size = 256
num_epochs = 100
image_size = 72  # We'll resize input images to this size
patch_size = 6  # Size of the patches to be extract from the input images
num_patches = (image_size // patch_size) ** 2
projection_dim = 64
num_heads = 4
transformer_units = [
    projection_dim * 2,
    projection_dim,
]  # Size of the transformer layers
transformer_layers = 8
mlp_head_units = [2048, 1024]  # Size of the dense layers of the final classifier

# %%
data_augmentation = keras.Sequential(
    [
        layers.Normalization(),
        layers.Resizing(image_size, image_size),
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(factor=0.02),
        layers.RandomZoom(
            height_factor=0.2, width_factor=0.2
        ),
    ],
    name="data_augmentation",
)
# Compute the mean and the variance of the training data for normalization.
data_augmentation.layers[0].adapt(X_train)

# %%
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x

# %%
class Patches(layers.Layer):
    def __init__(self, patch_size):
        super(Patches, self).__init__()
        self.patch_size = patch_size

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID",
        )
        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches, [batch_size, -1, patch_dims])
        return patches

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(4, 4))
image = X_train[np.random.choice(range(X_train.shape[0]))]
plt.imshow(image.astype("uint8"))
plt.axis("off")

resized_image = tf.image.resize(
    tf.convert_to_tensor([image]), size=(image_size, image_size)
)
patches = Patches(patch_size)(resized_image)
print(f"Image size: {image_size} X {image_size}")
print(f"Patch size: {patch_size} X {patch_size}")
print(f"Patches per image: {patches.shape[1]}")
print(f"Elements per patch: {patches.shape[-1]}")

n = int(np.sqrt(patches.shape[1]))
plt.figure(figsize=(4, 4))
for i, patch in enumerate(patches[0]):
    ax = plt.subplot(n, n, i + 1)
    patch_img = tf.reshape(patch, (patch_size, patch_size, 3))
    plt.imshow(patch_img.numpy().astype("uint8"))
    plt.axis("off")
# Out:
# Image size: 72 X 72
# Patch size: 6 X 6
# Patches per image: 144
# Elements per patch: 108

# %%
class PatchEncoder(layers.Layer):
    def __init__(self, num_patches, projection_dim):
        super(PatchEncoder, self).__init__()
        self.num_patches = num_patches
        self.projection = layers.Dense(units=projection_dim)
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )

    def call(self, patch):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        encoded = self.projection(patch) + self.position_embedding(positions)
        return encoded

# %%
#build ViT
def create_vit_classifier():
    inputs = layers.Input(shape=input_shape)
    # Augment data.
    augmented = data_augmentation(inputs)
    # Create patches.
    patches = Patches(patch_size)(augmented)
    # Encode patches.
    encoded_patches = PatchEncoder(num_patches, projection_dim)(patches)

    # Create multiple layers of the Transformer block.
    for _ in range(transformer_layers):
        # Layer normalization 1.
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        # Create a multi-head attention layer.
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=projection_dim, dropout=0.1
        )(x1, x1)
        # Skip connection 1.
        x2 = layers.Add()([attention_output, encoded_patches])
        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        # MLP.
        x3 = mlp(x3, hidden_units=transformer_units, dropout_rate=0.1)
        # Skip connection 2.
        encoded_patches = layers.Add()([x3, x2])

    # Create a [batch_size, projection_dim] tensor.
    representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
    representation = layers.Flatten()(representation)
    representation = layers.Dropout(0.5)(representation)
    # Add MLP.
    features = mlp(representation, hidden_units=mlp_head_units, dropout_rate=0.5)
    # Classify outputs.
    logits = layers.Dense(num_classes)(features)
    # Create the Keras model.
    model = keras.Model(inputs=inputs, outputs=logits)
    return model

# %%
def run_experiment(model):
    optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

    model.compile(
        optimizer=optimizer,
        loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=[
            keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
            keras.metrics.SparseTopKCategoricalAccuracy(5, name="top-5-accuracy"),
        ],
    )

#checkpoint path
    checkpoint_filepath = "/tmp/checkpoint"
    checkpoint_callback = keras.callbacks.ModelCheckpoint(
        checkpoint_filepath,
        monitor="val_accuracy",
        save_best_only=True,
        save_weights_only=True,
    )

    history = model.fit(
        x=X_train,
        y=ytrain,
        batch_size=batch_size,
        epochs=num_epochs,
        validation_split=0.1,
        callbacks=[checkpoint_callback],
    )

    model.load_weights(checkpoint_filepath)
    _, accuracy, top_5_accuracy = model.evaluate(X_test, ytest)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")
    print(f"Test top 5 accuracy: {round(top_5_accuracy * 100, 2)}%")

    return history


vit_classifier = create_vit_classifier()
history = run_experiment(vit_classifier)
# Out:
# Epoch 1/100
# 3/3 [==============================] - 16s 1s/step - loss: 7.3068 - accuracy: 0.4791 - top-5-accuracy: 1.0000 - val_loss: 10.6026 - val_accuracy: 0.5763 - val_top-5-accuracy: 1.0000
# Epoch 2/100
# 3/3 [==============================] - 1s 252ms/step - loss: 13.4114 - accuracy: 0.4981 - top-5-accuracy: 1.0000 - val_loss: 7.4243 - val_accuracy: 0.5763 - val_top-5-accuracy: 1.0000
# Epoch 3/100
# 3/3 [==============================] - 1s 248ms/step - loss: 7.0855 - accuracy: 0.5171 - top-5-accuracy: 1.0000 - val_loss: 2.5453 - val_accuracy: 0.4407 - val_top-5-accuracy: 1.0000
# Epoch 4/100
# 3/3 [==============================] - 1s 249ms/step - loss: 3.2814 - accuracy: 0.5019 - top-5-accuracy: 1.0000 - val_loss: 1.3074 - val_accuracy: 0.4237 - val_top-5-accuracy: 1.0000
# Epoch 5/100
# 3/3 [==============================] - 1s 255ms/step - loss: 1.9980 - accuracy: 0.5038 - top-5-accuracy: 1.0000 - val_loss: 1.7892 - val_accuracy: 0.5763 - val_top-5-accuracy: 1.0000
# ...
